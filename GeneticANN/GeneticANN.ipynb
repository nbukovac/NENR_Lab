# %%
import matplotlib.pyplot as plt
import numpy as np

f = lambda x, w, s : 1.0 / (1 + abs(x - w) / abs(s))
x = np.linspace(-8.0, 10.0)
y1 = []
y2 = []
y3 = []

w0 = 2
s1 = 1
s2 = 0.25
s3 = 4

for i in x:
    y1.append(f(i, w0, s1))
    y2.append(f(i, w0, s2))
    y3.append(f(i, w0, s3))
              
plt.figure(figsize=(16.,10.))
        
plt.plot(x, y1, c='red')
plt.plot(x, y2, c='blue')
plt.plot(x, y3, c='black')

plt.show()

# %%
x = []
y = []
classified = []

with open('dataset.txt') as f: 
    for line in f:
        split = line.split()
        x.append(float(split[0]))
        y.append(float(split[1]))
        
        if split[2] == '1':
            classified.append('red')
        elif split[3] == '1':
            classified.append('blue')
        else:
            classified.append('black')
            
plt.figure(figsize=(16.,10.))
plt.scatter(x, y, c=classified)
plt.show()

# %%
x = []
y = []
classified = []

with open('dataset.txt') as f: 
    for line in f:
        split = line.split()
        x.append(float(split[0]))
        y.append(float(split[1]))
        
        if split[2] == '1':
            classified.append('red')
        elif split[3] == '1':
            classified.append('blue')
        else:
            classified.append('black')
            
plt.figure(figsize=(16.,10.))
plt.scatter(x, y, c=classified)

wx = []
wy = []

with open('parameters.txt') as f:
    for line in f:
        split = line.split()
        print('s1 = ' + str(float(split[1])) + '\ts2 = ' + str(float(split[3])))
        wx.append(float(split[0]))
        wy.append(float(split[2]))
        
plt.scatter(wx, wy, c='orange', marker='s')
plt.show()
# Out:
# s1 = 0.0767993793232525	s2 = 0.173646098106778
# s1 = 0.12143226745308	s2 = 0.25210819976093
# s1 = -0.272041511917755	s2 = 0.374793069085809
# s1 = -0.139030512607129	s2 = 0.218809698962644
# s1 = -0.102555336015798	s2 = -0.252388163087948
# s1 = -0.121687901983229	s2 = 0.156392714298249
# s1 = 0.0788578943432068	s2 = -0.183495111859197
# s1 = 0.0723054362117555	s2 = -0.170669865125462
